# %% [markdown]
# # 3/9/21 - First fit to G585328_3234.

# %% [markdown]
# ## Experiment 1 : phase1_nlive = 200, phase1_tolerance = 0.5, phase2_nlive = 500, phase2_tolerance = 0.25, use effective radius from GAMA DR3 Sersic Photometry catalog (including errors) and upper limit (effective radius + error), normal mask, Source R_E (0->10*lens.inensity), 2 position, threshold=1.0
#
# ## Don't take the instance for the ellipticity and effective radius. Set same max effective radius.

# %%
### libraries
# %matplotlib inline
# set workspace path
from pyprojroot import here
workspace_path = str(here())#'/data/sknabel/autolens_workspace'
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

import matplotlib.pyplot as plt
from autoconf import conf
import autolens as al
import autolens.plot as aplt
import autofit as af
import pandas as pd
import numpy as np
from astropy.io import fits
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.stats import sigma_clip as clip
from os import path
import time

# set datetime variable
datetime = time.strftime("%d%m%y")
print(f'Today is {datetime}')
# paths
autoz_path = '/data/sknabel/autoz_lens_model/'
file_path = f'{autoz_path}files/'
csv_path = f'{file_path}csv/'
fits_path = f'{file_path}fits/'
png_path = f'{autoz_path}visuals/png/'
pdf_path = f'{autoz_path}visuals/pdf/'
# Out:
# /data/sknabel/autoz_lens_model
# Working Directory has been set to `/data/sknabel/autoz_lens_model`
# Today is 090321

# %%
# this should be constant across experiments

gama_id = 585328
links_id = 3234

object_folder = f'{fits_path}G{gama_id}_{links_id}/'
output_folder = f'{autoz_path}output/G{gama_id}_{links_id}/'

# load object data table
links = pd.read_csv(f'{csv_path}/latest/links_sample_latest.csv')
lens_galaxy_data = links[links.GAMA_ID == gama_id]
zlens=lens_galaxy_data.zlens.values
zsource=lens_galaxy_data.zsource.values
einstein_radius=np.mean([lens_galaxy_data.theta_e_pm.values, lens_galaxy_data.theta_e_sis.values]) # take average of einstein radius estimates for prior
print(f'Lens and source redshifts at {zlens} and {zsource}.')
print(f'Einstein radius prior: {einstein_radius}')

# effective radius and error from DR3 sersic catalog
hdul = fits.open(f'{fits_path}SersicCatSDSS.fits')
hdul.verify('fix')
data = hdul[1].data
#print(data.columns)
#print(data.CATAID)
candidate = data[data.CATAID == gama_id]
re_r = candidate.GALRE_r
re_r_err = candidate.GALREERR_r
re_g = candidate.GALRE_g
re_g_err = candidate.GALREERR_u


# load r-band imaging
imaging_r = al.Imaging.from_fits(image_path=path.join(object_folder, f'{links_id}_r_image.fits'),
                              noise_map_path=path.join(object_folder, f'{links_id}_r_noisemap.fits'),
                              psf_path=path.join(object_folder, f'{links_id}_r_psf.fits'),
                               pixel_scales=0.2)

# load g-band imaging
imaging_g = al.Imaging.from_fits(image_path=path.join(object_folder, f'{links_id}_g_image.fits'),
                              noise_map_path=path.join(object_folder, f'{links_id}_g_noisemap.fits'),
                              psf_path=path.join(object_folder, f'{links_id}_g_psf.fits'),
                               pixel_scales=0.2)

# set up mask
mask = al.Mask2D.circular(
    shape_native=imaging_r.shape_native, pixel_scales=imaging_r.pixel_scales, sub_size=2, radius=3.5, centre=(0, 0.6)
)
visuals_2d = aplt.Visuals2D(mask=mask)

# set positions
imaging_r.positions = al.Grid2DIrregular(
    [(-2.0, 2.0)]#, (-0.8, 1.0), (-1.0, 0.5), (0.3, 1.1)]
)
#visuals_2d = aplt.Visuals2D(mask=mask, positions=imaging_r.positions)
# plot subplots for first view
print('Plotting r-band')
imaging_plotter_r = aplt.ImagingPlotter( # this is where the noise is coming up weird
    imaging=imaging_r, visuals_2d=visuals_2d
)
imaging_plotter_r.figures(image=True)
imaging_plotter_r.subplot_imaging()

# set positions
imaging_g.positions = al.Grid2DIrregular(
    [(-2.0, 2.0)]#, (-0.8, 1.0), (-1.0, 0.5), (0.3, 1.1)]
)
# plot the image
#visuals_2d = aplt.Visuals2D(mask=mask, positions=imaging_g.positions)
imaging_plotter_g = aplt.ImagingPlotter(imaging=imaging_g, visuals_2d=visuals_2d)
imaging_plotter_g.figures(image=True)
print('Plotting g-band')
imaging_plotter_g = aplt.ImagingPlotter( # this is where the noise is coming up weird
    imaging=imaging_g, visuals_2d=visuals_2d
)
imaging_plotter_g.subplot_imaging()

# set up grid and settings
settings_masked_imaging = al.SettingsMaskedImaging(grid_class=al.Grid2D)#, psf_shape_2d=imaging.psf.shape_2d)
settings = al.SettingsPhaseImaging(settings_masked_imaging=settings_masked_imaging)

#set up lens light profile
lens_start = al.GalaxyModel(
    redshift=zlens, bulge=al.lp.EllipticalSersic#, mass=al.mp.EllipticalIsothermal
)

# set priors
# lens position
lens_start.bulge.centre_0 = af.UniformPrior(lower_limit=0.0, upper_limit=2.0)
lens_start.bulge.centre_1 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)
# effective radius
#lens_start.bulge.effective_radius = af.UniformPrior(lower_limit=0.0, upper_limit=5.0) # why have I chosen 3 here? because the mask is 3...
# Out:
# Lens and source redshifts at [0.20466271] and [0.78874117].
# Einstein radius prior: 1.0876736377169312
# Plotting r-band
# Plotting g-band
# /soft/anaconda3/lib/python3.7/site-packages/autoarray/dataset/abstract_dataset.py:88: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.0 / self.noise_map

# %% [markdown]
# # These may not be centered correctly... This is super frustrating. I'll just have to create my own cutouts if these don't work.

# %%
print(re_g_err)
# Out:
# [0.8061759]

# %%
# Start a pandas dataframe
performance_log = pd.DataFrame(columns=['Experiment', 
                                        'phase1_time', 
                                        'phase1_likelihood', 
                                        'phase2_time', 
                                        'phase2_likelihood' 
                                        ])

# load performance log from csv
#performance_log = pd.read_csv(f'{csv_path}G{gama_id}_{links_id}_performance_log.csv')
#print(performance_log)
#print(performance_log)

# %%
# set experiment number
experiment_number = '1'

lens_start.bulge.effective_radius = af.GaussianPrior(mean=re_r, sigma=re_r_err, lower_limit=0.0, upper_limit=re_r+re_r_err)

# set up mask
#lens_mask = al.Mask2D.circular(
#    shape_native=imaging_r.shape_native, pixel_scales=imaging_r.pixel_scales, sub_size=2, radius=re_r #centre=(0.075, -0.075) 
#)
#visuals_2d = aplt.Visuals2D(mask=lens_mask)

# I can probably use the regular mask for this.

# plot subplots for first view
print('Plotting r-band')
imaging_plotter_r = aplt.ImagingPlotter(
    imaging=imaging_r, visuals_2d=visuals_2d
)
imaging_plotter_r.subplot_imaging()

# set up phase
phase1 = al.PhaseImaging(
    search=af.DynestyStatic(
        path_prefix=f"{output_folder}", name=f"experiment_{experiment_number}_phase1_fit_{datetime}", n_live_points=200,
        evidence_tolerance=0.5, walks = 10
    ),
    settings=settings,
    galaxies=af.CollectionPriorModel(lens=lens_start)#, source=source)
)

print(lens_start)
# Out:
# Plotting r-band
# Galaxy (centre_0, UniformPrior, lower_limit = 0.0, upper_limit = 2.0), (centre_1, UniformPrior, lower_limit = -0.1, upper_limit = 0.1), (elliptical_comps_0, GaussianPrior, mean = 0.0, sigma = 0.3), (elliptical_comps_1, GaussianPrior, mean = 0.0, sigma = 0.3), (intensity, LogUniformPrior, lower_limit = 1e-06, upper_limit = 1000000.0), (effective_radius, GaussianPrior, mean = 2.5114476680755615, sigma = 0.0574943982064724), (sersic_index, UniformPrior, lower_limit = 0.5, upper_limit = 8.0)

# %%
# run the phase
print('Phase running...')
tick = time.perf_counter()
phase1_result = phase1.run(dataset=imaging_r, mask=mask)
tock = time.perf_counter()
print(f'Work complete! Took us {tock-tick} seconds or {(tock-tick)/60} minutes.')
# Out:
# Phase running...
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 532it [00:13, 38.89it/s, +200 | bound: 0 | nc: 1 | ncall: 2703 | eff(%): 27.081 | loglstar:   -inf < -10379.044 <    inf | logz: -10387.694 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 655it [00:13, 48.97it/s, +200 | bound: 0 | nc: 1 | ncall: 5231 | eff(%): 16.345 | loglstar:   -inf < -10379.044 <    inf | logz: -10388.307 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 763it [00:13, 57.33it/s, +200 | bound: 1 | nc: 1 | ncall: 7736 | eff(%): 12.448 | loglstar:   -inf < -10379.044 <    inf | logz: -10388.846 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 765it [00:00, 6215.07it/s, bound: 1 | nc: 10 | ncall: 7756 | eff(%):  9.863 | loglstar:   -inf < -21539.825 <    inf | logz: -21549.632 +/-    nan | dlogz: 11177.718 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 993it [00:14, 66.76it/s, +200 | bound: 10 | nc: 1 | ncall: 10237 | eff(%): 11.654 | loglstar:   -inf < -9612.541 <    inf | logz: -9623.490 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 995it [00:00, 7611.15it/s, bound: 10 | nc: 10 | ncall: 10257 | eff(%):  9.701 | loglstar:   -inf < -17554.143 <    inf | logz: -17565.097 +/-    nan | dlogz: 7964.041 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1209it [00:14, 85.10it/s, +200 | bound: 19 | nc: 1 | ncall: 12741 | eff(%): 11.059 | loglstar:   -inf < -9399.414 <    inf | logz: -9411.441 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1211it [00:00, 10628.96it/s, bound: 19 | nc: 10 | ncall: 12761 | eff(%):  9.490 | loglstar:   -inf < -14735.322 <    inf | logz: -14746.268 +/-    nan | dlogz: 5341.634 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1435it [00:13, 103.30it/s, +200 | bound: 27 | nc: 1 | ncall: 15250 | eff(%): 10.721 | loglstar:   -inf < -9227.399 <    inf | logz: -9240.552 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1654it [00:13, 120.60it/s, +200 | bound: 36 | nc: 1 | ncall: 17762 | eff(%): 10.438 | loglstar:   -inf < -8793.238 <    inf | logz: -8807.483 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:17500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1656it [00:00, 13984.03it/s, bound: 36 | nc: 11 | ncall: 17783 | eff(%):  9.312 | loglstar:   -inf < -11250.829 <    inf | logz: -11263.973 +/-    nan | dlogz: 2463.285 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 1877it [00:13, 136.89it/s, +200 | bound: 47 | nc: 1 | ncall: 20268 | eff(%): 10.248 | loglstar:   -inf < -8527.708 <    inf | logz: -8543.066 +/-    nan | dlogz:  1.099 >  0.500]
# INFO:root:20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2100it [00:13, 155.05it/s, +200 | bound: 56 | nc: 1 | ncall: 22775 | eff(%): 10.099 | loglstar:   -inf < -8527.708 <    inf | logz: -8544.178 +/-  0.192 | dlogz:  1.099 >  0.500]
# INFO:root:22500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2319it [00:13, 172.33it/s, +200 | bound: 65 | nc: 1 | ncall: 25280 | eff(%):  9.964 | loglstar:   -inf < -8138.144 <    inf | logz: -8155.707 +/-  0.143 | dlogz:  1.099 >  0.500]
# INFO:root:25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2537it [00:13, 188.22it/s, +200 | bound: 74 | nc: 1 | ncall: 27792 | eff(%):  9.848 | loglstar:   -inf < -8108.758 <    inf | logz: -8127.408 +/-  0.142 | dlogz:  1.099 >  0.500]
# INFO:root:27500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2769it [00:13, 206.23it/s, +200 | bound: 82 | nc: 1 | ncall: 30294 | eff(%):  9.801 | loglstar:   -inf < -8108.758 <    inf | logz: -8128.565 +/-  0.243 | dlogz:  1.099 >  0.500]
# INFO:root:30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2993it [00:13, 222.62it/s, +200 | bound: 91 | nc: 1 | ncall: 32802 | eff(%):  9.734 | loglstar:   -inf < -8079.142 <    inf | logz: -8100.023 +/-    nan | dlogz:  1.070 >  0.500]
# INFO:root:32500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3217it [00:13, 238.77it/s, +200 | bound: 100 | nc: 1 | ncall: 35306 | eff(%):  9.678 | loglstar:   -inf < -8079.142 <    inf | logz: -8101.047 +/-  0.500 | dlogz:  1.009 >  0.500]
# INFO:root:35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3434it [00:13, 255.15it/s, +200 | bound: 109 | nc: 1 | ncall: 37815 | eff(%):  9.610 | loglstar:   -inf < -8035.279 <    inf | logz: -8058.402 +/-  0.819 | dlogz:  1.099 >  0.500]
# INFO:root:37500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3666it [00:13, 271.15it/s, +200 | bound: 118 | nc: 1 | ncall: 40322 | eff(%):  9.588 | loglstar:   -inf < -8012.192 <    inf | logz: -8036.414 +/-  0.533 | dlogz:  1.060 >  0.500]
# INFO:root:40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3899it [00:13, 289.28it/s, +200 | bound: 127 | nc: 1 | ncall: 42827 | eff(%):  9.571 | loglstar:   -inf < -8012.192 <    inf | logz: -8037.565 +/-  1.048 | dlogz:  1.053 >  0.500]
# INFO:root:42500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4120it [00:13, 305.35it/s, +200 | bound: 135 | nc: 1 | ncall: 45336 | eff(%):  9.529 | loglstar:   -inf < -8005.155 <    inf | logz: -8031.347 +/-  0.582 | dlogz:  0.877 >  0.500]
# INFO:root:45000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4348it [00:13, 322.36it/s, +200 | bound: 143 | nc: 1 | ncall: 47838 | eff(%):  9.507 | loglstar:   -inf < -8000.256 <    inf | logz: -8027.208 +/-  0.821 | dlogz:  0.675 >  0.500]
# INFO:root:47500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4574it [00:13, 339.05it/s, +200 | bound: 152 | nc: 1 | ncall: 50339 | eff(%):  9.484 | loglstar:   -inf < -7990.112 <    inf | logz: -8018.921 +/-  1.782 | dlogz:  1.098 >  0.500]
# INFO:root:50000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 4801it [00:13, 357.68it/s, +200 | bound: 161 | nc: 1 | ncall: 52842 | eff(%):  9.464 | loglstar:   -inf < -7980.403 <    inf | logz: -8010.344 +/-  1.660 | dlogz:  1.098 >  0.500]
# INFO:root:52500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5021it [00:13, 374.03it/s, +200 | bound: 170 | nc: 1 | ncall: 55345 | eff(%):  9.434 | loglstar:   -inf < -7978.142 <    inf | logz: -8008.951 +/-  1.190 | dlogz:  0.951 >  0.500]
# INFO:root:55000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5246it [00:13, 387.83it/s, +200 | bound: 178 | nc: 1 | ncall: 57846 | eff(%):  9.415 | loglstar:   -inf < -7978.142 <    inf | logz: -8010.040 +/-  1.456 | dlogz:  0.931 >  0.500]
# INFO:root:57500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5470it [00:13, 403.84it/s, +200 | bound: 187 | nc: 1 | ncall: 60351 | eff(%):  9.395 | loglstar:   -inf < -7971.910 <    inf | logz: -8005.049 +/-  1.513 | dlogz:  1.008 >  0.500]
# INFO:root:60000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5692it [00:13, 418.61it/s, +200 | bound: 195 | nc: 1 | ncall: 62861 | eff(%):  9.373 | loglstar:   -inf < -7971.910 <    inf | logz: -8004.680 +/-  0.782 | dlogz:  0.335 >  0.500]
# INFO:root:62500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5694it [00:00, 51398.39it/s, bound: 195 | nc: 10 | ncall: 62881 | eff(%):  9.055 | loglstar:   -inf < -7987.241 <    inf | logz: -8016.905 +/-  0.209 | dlogz: 16.619 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 5768it [00:14, 401.83it/s, +200 | bound: 202 | nc: 1 | ncall: 65560 | eff(%):  9.103 | loglstar:   -inf < -7966.262 <    inf | logz: -8000.977 +/-  1.892 | dlogz:  1.066 >  0.500]
# INFO:root:65000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 5961it [00:13, 441.35it/s, +200 | bound: 211 | nc: 1 | ncall: 68064 | eff(%):  9.052 | loglstar:   -inf < -7961.453 <    inf | logz: -7997.058 +/-  1.478 | dlogz:  1.019 >  0.500]
# INFO:root:67500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6148it [00:13, 454.96it/s, +200 | bound: 219 | nc: 1 | ncall: 70571 | eff(%):  8.995 | loglstar:   -inf < -7961.453 <    inf | logz: -7997.764 +/-  1.341 | dlogz:  0.880 >  0.500]
# INFO:root:70000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6353it [00:13, 468.31it/s, +200 | bound: 227 | nc: 1 | ncall: 73075 | eff(%):  8.967 | loglstar:   -inf < -7961.453 <    inf | logz: -7998.766 +/-  1.567 | dlogz:  0.868 >  0.500]
# INFO:root:72500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6545it [00:13, 478.15it/s, +200 | bound: 236 | nc: 1 | ncall: 75596 | eff(%):  8.922 | loglstar:   -inf < -7960.660 <    inf | logz: -7998.191 +/-  1.192 | dlogz:  0.507 >  0.500]
# INFO:root:75000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6753it [00:13, 497.17it/s, +200 | bound: 245 | nc: 1 | ncall: 78103 | eff(%):  8.902 | loglstar:   -inf < -7960.215 <    inf | logz: -7998.072 +/-  0.921 | dlogz:  0.281 >  0.500]
# INFO:root:77500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 6963it [00:13, 512.57it/s, +200 | bound: 253 | nc: 1 | ncall: 80608 | eff(%):  8.886 | loglstar:   -inf < -7951.674 <    inf | logz: -7992.376 +/-  2.112 | dlogz:  1.083 >  0.500]
# INFO:root:80000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7157it [00:13, 521.10it/s, +200 | bound: 262 | nc: 1 | ncall: 83109 | eff(%):  8.852 | loglstar:   -inf < -7951.674 <    inf | logz: -7993.327 +/-  2.317 | dlogz:  1.072 >  0.500]
# INFO:root:82500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7361it [00:13, 537.19it/s, +200 | bound: 272 | nc: 1 | ncall: 85622 | eff(%):  8.831 | loglstar:   -inf < -7951.674 <    inf | logz: -7993.811 +/-  1.678 | dlogz:  0.755 >  0.500]
# INFO:root:85000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7560it [00:13, 554.84it/s, +200 | bound: 280 | nc: 1 | ncall: 88128 | eff(%):  8.805 | loglstar:   -inf < -7951.674 <    inf | logz: -7994.294 +/-  1.375 | dlogz:  0.517 >  0.500]
# INFO:root:87500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7762it [00:13, 565.58it/s, +200 | bound: 289 | nc: 1 | ncall: 90644 | eff(%):  8.784 | loglstar:   -inf < -7948.929 <    inf | logz: -7992.997 +/-  1.785 | dlogz:  0.719 >  0.500]
# INFO:root:90000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 7957it [00:13, 584.77it/s, +200 | bound: 298 | nc: 1 | ncall: 93154 | eff(%):  8.756 | loglstar:   -inf < -7948.929 <    inf | logz: -7993.290 +/-  1.550 | dlogz:  0.428 >  0.500]
# INFO:root:92500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8159it [00:13, 602.29it/s, +200 | bound: 306 | nc: 1 | ncall: 95661 | eff(%):  8.738 | loglstar:   -inf < -7948.115 <    inf | logz: -7992.784 +/-  1.296 | dlogz:  0.235 >  0.500]
# INFO:root:95000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8368it [00:13, 610.15it/s, +200 | bound: 316 | nc: 1 | ncall: 98171 | eff(%):  8.728 | loglstar:   -inf < -7946.791 <    inf | logz: -7992.191 +/-  1.019 | dlogz:  0.178 >  0.500]
# INFO:root:97500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8560it [00:13, 624.82it/s, +200 | bound: 324 | nc: 1 | ncall: 100679 | eff(%):  8.701 | loglstar:   -inf < -7944.334 <    inf | logz: -7991.789 +/-  1.489 | dlogz:  0.459 >  0.500]
# INFO:root:100000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8742it [00:13, 636.91it/s, +200 | bound: 332 | nc: 1 | ncall: 103181 | eff(%):  8.666 | loglstar:   -inf < -7944.334 <    inf | logz: -7991.407 +/-  1.088 | dlogz:  0.149 >  0.500]
# INFO:root:102500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 8945it [00:13, 656.50it/s, +200 | bound: 340 | nc: 1 | ncall: 105687 | eff(%):  8.653 | loglstar:   -inf < -7940.650 <    inf | logz: -7990.316 +/-  1.650 | dlogz:  0.575 >  0.500]
# INFO:root:105000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9143it [00:13, 672.07it/s, +200 | bound: 350 | nc: 1 | ncall: 108195 | eff(%):  8.635 | loglstar:   -inf < -7939.849 <    inf | logz: -7989.914 +/-  1.535 | dlogz:  0.359 >  0.500]
# INFO:root:107500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9356it [00:13, 679.45it/s, +200 | bound: 360 | nc: 1 | ncall: 110704 | eff(%):  8.632 | loglstar:   -inf < -7939.849 <    inf | logz: -7989.862 +/-  1.005 | dlogz:  0.133 >  0.500]
# INFO:root:110000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9557it [00:13, 699.22it/s, +200 | bound: 371 | nc: 1 | ncall: 113213 | eff(%):  8.618 | loglstar:   -inf < -7936.371 <    inf | logz: -7988.706 +/-  1.587 | dlogz:  0.426 >  0.500]
# INFO:root:112500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9773it [00:13, 705.64it/s, +200 | bound: 379 | nc: 1 | ncall: 115720 | eff(%):  8.618 | loglstar:   -inf < -7936.283 <    inf | logz: -7988.543 +/-  1.209 | dlogz:  0.155 >  0.500]
# INFO:root:115000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 9975it [00:13, 725.43it/s, +200 | bound: 388 | nc: 1 | ncall: 118228 | eff(%):  8.606 | loglstar:   -inf < -7934.990 <    inf | logz: -7988.256 +/-  1.202 | dlogz:  0.155 >  0.500]
# INFO:root:117500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10170it [00:13, 742.52it/s, +200 | bound: 398 | nc: 1 | ncall: 120736 | eff(%):  8.589 | loglstar:   -inf < -7933.865 <    inf | logz: -7987.834 +/-  1.136 | dlogz:  0.120 >  0.500]
# INFO:root:120000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10368it [00:13, 756.56it/s, +200 | bound: 407 | nc: 1 | ncall: 123245 | eff(%):  8.575 | loglstar:   -inf < -7931.841 <    inf | logz: -7987.455 +/-  1.231 | dlogz:  0.220 >  0.500]
# INFO:root:122500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10574it [00:13, 774.92it/s, +200 | bound: 416 | nc: 1 | ncall: 125751 | eff(%):  8.568 | loglstar:   -inf < -7928.255 <    inf | logz: -7986.354 +/-  2.141 | dlogz:  0.722 >  0.500]
# INFO:root:125000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10786it [00:13, 774.91it/s, +200 | bound: 424 | nc: 1 | ncall: 128255 | eff(%):  8.566 | loglstar:   -inf < -7928.255 <    inf | logz: -7986.588 +/-  1.671 | dlogz:  0.382 >  0.500]
# INFO:root:127500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 10971it [00:13, 803.62it/s, +200 | bound: 432 | nc: 1 | ncall: 130763 | eff(%):  8.543 | loglstar:   -inf < -7926.568 <    inf | logz: -7986.002 +/-  1.692 | dlogz:  0.442 >  0.500]
# INFO:root:130000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 11177it [00:13, 799.53it/s, +200 | bound: 440 | nc: 1 | ncall: 133298 | eff(%):  8.535 | loglstar:   -inf < -7925.771 <    inf | logz: -7985.790 +/-  1.537 | dlogz:  0.305 >  0.500]
# INFO:root:132500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 11378it [00:13, 830.94it/s, +200 | bound: 449 | nc: 1 | ncall: 135804 | eff(%):  8.526 | loglstar:   -inf < -7923.198 <    inf | logz: -7985.165 +/-  2.113 | dlogz:  0.651 >  0.500]
# INFO:root:135000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 11559it [00:13, 843.34it/s, +200 | bound: 457 | nc: 1 | ncall: 138305 | eff(%):  8.502 | loglstar:   -inf < -7923.198 <    inf | logz: -7985.331 +/-  1.546 | dlogz:  0.365 >  0.500]
# INFO:root:137500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 11743it [00:13, 855.62it/s, +200 | bound: 466 | nc: 1 | ncall: 140806 | eff(%):  8.482 | loglstar:   -inf < -7923.198 <    inf | logz: -7985.108 +/-  1.305 | dlogz:  0.132 >  0.500]
# INFO:root:140000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 11939it [00:13, 872.25it/s, +200 | bound: 474 | nc: 1 | ncall: 143315 | eff(%):  8.470 | loglstar:   -inf < -7923.198 <    inf | logz: -7985.062 +/-  0.999 | dlogz:  0.049 >  0.500]
# INFO:root:142500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 12145it [00:14, 862.04it/s, +200 | bound: 482 | nc: 1 | ncall: 145822 | eff(%):  8.466 | loglstar:   -inf < -7919.009 <    inf | logz: -7984.514 +/-  1.937 | dlogz:  0.524 >  0.500]
# INFO:root:145000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 12344it [00:14, 858.51it/s, +200 | bound: 491 | nc: 1 | ncall: 148443 | eff(%):  8.450 | loglstar:   -inf < -7917.867 <    inf | logz: -7983.714 +/-  1.706 | dlogz:  0.307 >  0.500]
# INFO:root:147500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 12346it [00:00, 104115.69it/s, bound: 491 | nc: 10 | ncall: 148463 | eff(%):  8.316 | loglstar:   -inf < -7925.296 <    inf | logz: -7985.678 +/-  0.569 | dlogz:  6.244 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12413it [03:06, 66.64it/s, +200 | bound: 495 | nc: 1 | ncall: 183087 | eff(%):  6.889 | loglstar:   -inf < -7917.867 <    inf | logz: -7983.866 +/-  1.599 | dlogz:  0.260 >  0.500]
# INFO:root:150000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 12636it [00:13, 919.20it/s, +200 | bound: 504 | nc: 1 | ncall: 185593 | eff(%):  6.916 | loglstar:   -inf < -7917.266 <    inf | logz: -7983.939 +/-  1.400 | dlogz:  0.175 >  0.500]
# INFO:root:152500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 12830it [00:13, 936.56it/s, +200 | bound: 513 | nc: 1 | ncall: 188097 | eff(%):  6.927 | loglstar:   -inf < -7917.266 <    inf | logz: -7983.979 +/-  1.150 | dlogz:  0.073 >  0.500]
# INFO:root:155000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13007it [00:13, 936.51it/s, +200 | bound: 522 | nc: 1 | ncall: 190604 | eff(%):  6.929 | loglstar:   -inf < -7917.266 <    inf | logz: -7983.987 +/-  0.928 | dlogz:  0.031 >  0.500]
# INFO:root:157500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13008it [00:00, 129104.67it/s, bound: 522 | nc: 18 | ncall: 190622 | eff(%):  6.824 | loglstar:   -inf < -7921.396 <    inf | logz: -7984.783 +/-  0.592 | dlogz:  2.714 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 13180it [03:13, 68.07it/s, +200 | bound: 530 | nc: 1 | ncall: 227058 | eff(%):  5.893 | loglstar:   -inf < -7914.038 <    inf | logz: -7983.559 +/-  1.597 | dlogz:  0.198 >  0.500]
# INFO:root:160000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13410it [00:14, 953.78it/s, +200 | bound: 539 | nc: 1 | ncall: 229563 | eff(%):  5.929 | loglstar:   -inf < -7914.038 <    inf | logz: -7983.729 +/-  1.171 | dlogz:  0.079 >  0.500]
# INFO:root:162500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13614it [00:13, 989.16it/s, +200 | bound: 549 | nc: 1 | ncall: 232070 | eff(%):  5.953 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.017 +/-  2.346 | dlogz:  0.582 >  0.500]
# INFO:root:165000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13796it [00:13, 986.69it/s, +200 | bound: 558 | nc: 1 | ncall: 234574 | eff(%):  5.967 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.203 +/-  1.764 | dlogz:  0.325 >  0.500]
# INFO:root:167500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13941it [00:13, 1014.67it/s, +200 | bound: 565 | nc: 1 | ncall: 237077 | eff(%):  5.965 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.260 +/-  1.406 | dlogz:  0.180 >  0.500]
# INFO:root:170000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 13943it [00:00, 122691.05it/s, bound: 565 | nc: 10 | ncall: 237097 | eff(%):  5.881 | loglstar:   -inf < -7916.370 <    inf | logz: -7983.940 +/-  0.617 | dlogz:  4.367 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14046it [04:35, 50.97it/s, +200 | bound: 570 | nc: 1 | ncall: 289040 | eff(%):  4.929 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.242 +/-  1.242 | dlogz:  0.108 >  0.500]
# INFO:root:172500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14048it [00:00, 104130.99it/s, bound: 571 | nc: 10 | ncall: 289060 | eff(%):  4.860 | loglstar:   -inf < -7915.668 <    inf | logz: -7983.863 +/-  0.620 | dlogz:  3.777 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14058it [00:14, 1002.25it/s, +200 | bound: 572 | nc: 1 | ncall: 291637 | eff(%):  4.889 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.242 +/-  1.217 | dlogz:  0.102 >  0.500]
# INFO:root:175000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14060it [00:00, 103621.29it/s, bound: 573 | nc: 10 | ncall: 291657 | eff(%):  4.821 | loglstar:   -inf < -7915.586 <    inf | logz: -7983.854 +/-  0.621 | dlogz:  3.709 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14179it [03:28, 68.08it/s, +200 | bound: 577 | nc: 1 | ncall: 330833 | eff(%):  4.346 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.251 +/-  1.037 | dlogz:  0.058 >  0.500]
# INFO:root:177500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14181it [00:00, 104735.18it/s, bound: 578 | nc: 10 | ncall: 330853 | eff(%):  4.286 | loglstar:   -inf < -7914.871 <    inf | logz: -7983.760 +/-  0.624 | dlogz:  3.036 >  0.500]/soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:238: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# /soft/anaconda3/lib/python3.7/site-packages/dynesty/sampling.py:216: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14188it [00:18, 764.21it/s, +200 | bound: 579 | nc: 1 | ncall: 334247 | eff(%):  4.305 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.253 +/-  1.024 | dlogz:  0.055 >  0.500]
# INFO:root:180000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14399it [00:15, 927.53it/s, +200 | bound: 588 | nc: 1 | ncall: 337096 | eff(%):  4.331 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.230 +/-  0.860 | dlogz:  0.019 >  0.500]
# INFO:root:182500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14529it [00:13, 1048.12it/s, +200 | bound: 596 | nc: 1 | ncall: 339598 | eff(%):  4.337 | loglstar:   -inf < -7910.050 <    inf | logz: -7983.217 +/-  0.806 | dlogz:  0.010 >  0.500]
# INFO:root:185000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14743it [00:13, 1070.71it/s, +200 | bound: 605 | nc: 1 | ncall: 342105 | eff(%):  4.368 | loglstar:   -inf < -7909.446 <    inf | logz: -7983.194 +/-  0.772 | dlogz:  0.006 >  0.500]
# INFO:root:187500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14910it [00:13, 1088.44it/s, +200 | bound: 613 | nc: 1 | ncall: 344617 | eff(%):  4.385 | loglstar:   -inf < -7909.379 <    inf | logz: -7983.183 +/-  0.723 | dlogz:  0.003 >  0.500]
# INFO:root:190000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14915it [00:00, 48329.43it/s, +200 | bound: 613 | nc: 1 | ncall: 344671 | eff(%):  4.385 | loglstar:   -inf < -7909.379 <    inf | logz: -7983.182 +/-  0.722 | dlogz:  0.003 >  0.500]
# INFO:root:192500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 14915it [00:00, 2160302.65it/s, +200 | bound: 613 | nc: 1 | ncall: 344671 | eff(%):  4.385 | loglstar:   -inf < -7909.379 <    inf | logz: -7983.182 +/-  0.722 | dlogz:  0.003 >  0.500]
# INFO:root:195000 Iterations: Performing update (Visualization, outputting samples, etc.).
# INFO:root:197500 Iterations: Performing update (Visualization, outputting samples, etc.).
# Work complete! Took us 2462.0816279836 seconds or 41.03469379972667 minutes.

# %%
# write the results to the log
print(f'Log likelihood: {phase1_result.log_likelihood}')
print(f'Model: {phase1_result.model}')

phase1_time = tock-tick

# plot it!
fit_imaging_plotter = aplt.FitImagingPlotter(fit=phase1_result.max_log_likelihood_fit)
fit_imaging_plotter.subplot_fit_imaging()
# Out:
# Log likelihood: -7909.378620683243
# Model: Galaxy (centre_0, GaussianPrior, mean = 0.06119774936969661, sigma = 0.05), (centre_1, GaussianPrior, mean = 0.09989533316623628, sigma = 0.05), (elliptical_comps_0, GaussianPrior, mean = -0.1372742565673583, sigma = 0.2), (elliptical_comps_1, GaussianPrior, mean = 0.3592048812080911, sigma = 0.2), (intensity, GaussianPrior, mean = 1.0935301820192493, sigma = 0.5467650910096247), (effective_radius, GaussianPrior, mean = 2.060939676533616, sigma = 2.060939676533616), (sersic_index, GaussianPrior, mean = 1.3851364441682068, sigma = 1.5), None, None

# %%
# now phase 2!

#set up lens and source

# set stellar mass/light profile
bulge = af.PriorModel(al.lmp.EllipticalSersic)
bulge.take_attributes(source=phase1_result.model.galaxies.lens.bulge)

# set dark matter profile
dark = af.PriorModel(al.mp.SphericalNFWMCRLudlow)
dark.mass_at_200 = af.LogUniformPrior(lower_limit=1e8, upper_limit=1e15)
dark.redshift_object = zlens
dark.redshift_source = zsource

lens = al.GalaxyModel(
    redshift=zlens, bulge=bulge, dark=dark
)

source = al.GalaxyModel(
    redshift=zsource, bulge=al.lp.SphericalExponential)

# make lens intensity default to 0.1 +- 0.1 because red to green makes it wonky
#lens.bulge.intensity = af.GaussianPrior(mean=0.1, sigma=0.1)

# set uniform m_l ratio
#lens.bulge.mass_to_light_ratio = af.UniformPrior(lower_limit=0.0, upper_limit=100000.0) # leave it default

# make dark matter centered at stellar mass center
lens.bulge.centre = phase1_result.instance.galaxies.lens.bulge.centre
lens.dark.centre = lens.bulge.centre

# make lens effective radius for g-band
lens.bulge.effective_radius = af.GaussianPrior(mean=re_g, sigma=re_g_err, lower_limit=0.0, upper_limit=re_g+re_g_err)

# einstein radius
#lens.mass.einstein_radius = af.GaussianPrior(mean=einstein_radius, sigma=0.3*einstein_radius) # take sigma to be 30% of mean # hmmm

# source position
source.bulge.centre_0 = af.UniformPrior(lower_limit=-3, upper_limit=3)
source.bulge.centre_1 = af.UniformPrior(lower_limit=-3, upper_limit=3)
source.bulge.effective_radius = af.UniformPrior(lower_limit=0.0, upper_limit=5.0)
#source.bulge.intensity = af.UniformPrior(lower_limit=0.0, upper_limit=10*lens.bulge.intensity)

print(f'Lens: {lens}')
print(f'Source: {source}')
# Out:
# Lens: Galaxy (elliptical_comps_0, GaussianPrior, mean = -0.05114413191431855, sigma = 0.2), (elliptical_comps_1, GaussianPrior, mean = 0.08266476865210554, sigma = 0.2), (intensity, GaussianPrior, mean = 1.0404389009197414, sigma = 0.5202194504598707), (effective_radius, GaussianPrior, mean = 1.4225456714630127, sigma = 85.1292724609375), (sersic_index, GaussianPrior, mean = 2.0436969632235398, sigma = 1.5), (mass_to_light_ratio, LogUniformPrior, lower_limit = 1e-06, upper_limit = 1000000.0), (mass_at_200, LogUniformPrior, lower_limit = 100000000.0, upper_limit = 1000000000000000.0)
# Source: Galaxy (centre_0, UniformPrior, lower_limit = -3.0, upper_limit = 3.0), (centre_1, UniformPrior, lower_limit = -3.0, upper_limit = 3.0), (intensity, LogUniformPrior, lower_limit = 1e-06, upper_limit = 1000000.0), (effective_radius, UniformPrior, lower_limit = 0.0, upper_limit = 5.0)

# %%
# Set up the positions... (GUI is not working...)

# plot the r-band image to see it
print('Plotting g-band')
imaging_plotter_g = aplt.ImagingPlotter( # this is where the noise is coming up weird
    imaging=imaging_g, visuals_2d=aplt.Visuals2D(mask=mask)
)
imaging_plotter_g.figures(image=True)

# set positions
imaging_g.positions = al.Grid2DIrregular(
    [(0.9, 0.9), (0.0, 1.2), (-0.9, 0.9)]#, (-0.8, 1.0), (-1.0, 0.5), (0.3, 1.1)]
)

# plot the image
visuals_2d = aplt.Visuals2D(mask=mask, positions=imaging_g.positions)
imaging_plotter_g = aplt.ImagingPlotter(imaging=imaging_g, visuals_2d=visuals_2d)
imaging_plotter_g.figures(image=True)
# Out:
# Plotting g-band

# %%
# set the settings to include the positions
settings_lens = al.SettingsLens(positions_threshold=1.0)

settings = al.SettingsPhaseImaging(
    settings_masked_imaging=settings_masked_imaging, settings_lens=settings_lens
)

# %%
# set up phase
phase2 = al.PhaseImaging(
    search=af.DynestyStatic(
        path_prefix=f'{output_folder}', name=f"experiment_{experiment_number}_phase2_fit_{datetime}", n_live_points=500,
        evidence_tolerance=0.25, walks=10, facc=0.4
    ),
    settings=settings,
    galaxies=af.CollectionPriorModel(lens=lens, source=source)#, source=source)
)

# %%
# run phase
# run the phase
print('Phase running...')
tick = time.perf_counter()
phase2_result = phase2.run(dataset=imaging_g, mask=mask)
tock = time.perf_counter()
print(f'Work complete! Took us {tock-tick} seconds or {(tock-tick)/60} minutes.')
# Out:
# INFO:root:Generating initial samples of model, which are subject to prior limits and other constraints.
# Phase running...
# INFO:root:No Dynesty samples found, beginning new non-linear search.
# 190it [01:18,  2.42it/s, +500 | bound: 3 | nc: 1 | ncall: 3002 | eff(%): 22.985 | loglstar:   -inf < 48.959 <    inf | logz: 41.669 +/-  0.610 | dlogz:  1.099 >  0.250]
# INFO:root:2500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 422it [01:37,  4.34it/s, +500 | bound: 6 | nc: 1 | ncall: 5503 | eff(%): 16.754 | loglstar:   -inf < 101.099 <    inf | logz: 93.346 +/-  0.495 | dlogz:  1.099 >  0.250]
# INFO:root:5000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 644it [01:37,  6.62it/s, +500 | bound: 11 | nc: 1 | ncall: 8005 | eff(%): 14.291 | loglstar:   -inf < 101.099 <    inf | logz: 92.964 +/-    nan | dlogz:  1.058 >  0.250]
# INFO:root:7500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 880it [01:41,  8.70it/s, +500 | bound: 14 | nc: 1 | ncall: 10515 | eff(%): 13.124 | loglstar:   -inf < 112.772 <    inf | logz: 104.104 +/-  0.797 | dlogz:  1.099 >  0.250]
# INFO:root:10000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1097it [01:40, 10.86it/s, +500 | bound: 18 | nc: 1 | ncall: 13022 | eff(%): 12.264 | loglstar:   -inf < 142.893 <    inf | logz: 134.885 +/-    nan | dlogz:  0.513 >  0.250]
# INFO:root:12500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1278it [01:33, 13.61it/s, +500 | bound: 21 | nc: 1 | ncall: 15531 | eff(%): 11.448 | loglstar:   -inf < 146.273 <    inf | logz: 136.937 +/-  0.423 | dlogz:  1.015 >  0.250]
# INFO:root:15000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1490it [01:40, 14.76it/s, +500 | bound: 24 | nc: 1 | ncall: 18038 | eff(%): 11.032 | loglstar:   -inf < 146.273 <    inf | logz: 136.722 +/-    nan | dlogz:  0.887 >  0.250]
# INFO:root:17500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1708it [01:51, 15.26it/s, +500 | bound: 27 | nc: 1 | ncall: 20554 | eff(%): 10.742 | loglstar:   -inf < 146.273 <    inf | logz: 136.287 +/-  0.160 | dlogz:  0.887 >  0.250]
# INFO:root:20000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 1934it [01:52, 17.17it/s, +500 | bound: 31 | nc: 1 | ncall: 23060 | eff(%): 10.555 | loglstar:   -inf < 146.325 <    inf | logz: 136.738 +/-    nan | dlogz:  0.476 >  0.250]
# INFO:root:22500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2149it [02:03, 17.37it/s, +500 | bound: 34 | nc: 1 | ncall: 25565 | eff(%): 10.362 | loglstar:   -inf < 159.672 <    inf | logz: 148.468 +/-  1.518 | dlogz:  1.099 >  0.250]
# INFO:root:25000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2363it [01:51, 21.19it/s, +500 | bound: 37 | nc: 1 | ncall: 28072 | eff(%): 10.199 | loglstar:   -inf < 159.672 <    inf | logz: 148.041 +/-  1.657 | dlogz:  1.099 >  0.250]
# INFO:root:27500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2578it [02:03, 20.90it/s, +500 | bound: 41 | nc: 1 | ncall: 30577 | eff(%): 10.066 | loglstar:   -inf < 159.672 <    inf | logz: 147.619 +/-  1.349 | dlogz:  1.093 >  0.250]
# INFO:root:30000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 2805it [02:18, 20.27it/s, +500 | bound: 44 | nc: 1 | ncall: 33085 | eff(%):  9.989 | loglstar:   -inf < 159.672 <    inf | logz: 147.341 +/-  0.936 | dlogz:  0.980 >  0.250]
# INFO:root:32500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3005it [02:13, 22.46it/s, +500 | bound: 48 | nc: 1 | ncall: 35653 | eff(%):  9.831 | loglstar:   -inf < 162.011 <    inf | logz: 149.290 +/-  0.961 | dlogz:  0.974 >  0.250]
# INFO:root:35000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3104it [02:25, 21.30it/s, +500 | bound: 50 | nc: 1 | ncall: 38158 | eff(%):  9.445 | loglstar:   -inf < 162.011 <    inf | logz: 149.281 +/-  0.881 | dlogz:  0.861 >  0.250]
# INFO:root:37500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3311it [02:12, 24.96it/s, +500 | bound: 54 | nc: 1 | ncall: 40660 | eff(%):  9.373 | loglstar:   -inf < 162.011 <    inf | logz: 148.870 +/-  1.049 | dlogz:  0.860 >  0.250]
# INFO:root:40000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3534it [02:12, 26.63it/s, +500 | bound: 57 | nc: 1 | ncall: 43175 | eff(%):  9.343 | loglstar:   -inf < 162.011 <    inf | logz: 148.961 +/-  0.745 | dlogz:  0.586 >  0.250]
# INFO:root:42500 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3768it [02:21, 26.68it/s, +500 | bound: 61 | nc: 1 | ncall: 45684 | eff(%):  9.342 | loglstar:   -inf < 163.344 <    inf | logz: 149.741 +/-  0.940 | dlogz:  0.625 >  0.250]
# INFO:root:45000 Iterations: Performing update (Visualization, outputting samples, etc.).
# 3877it [01:06,  1.55it/s, bound: 62 | nc: 10 | ncall: 46833 | eff(%):  8.278 | loglstar:   -inf < 130.799 <    inf | logz: 120.038 +/-  0.124 | dlogz: 35.602 >  0.250]

# %%
# write the results to the log
print(f'Log likelihood: {phase2_result.log_likelihood}')
print(f'Model: {phase2_result.model}')

phase2_time=tock-tick

log = open(f"{output_folder}experiment_log", 'a') # append the log
lines = [f'Experiment {experiment_number} \n',
         f'r-band \n',
         f'Time to convergence: {phase1_time} seconds \n', 
         f'Log likelihood: {phase1_result.log_likelihood} \n',
         f'Model: {str(phase1_result.model)} \n',
         f'g-band \n',
         f'Time to convergence: {phase2_time} seconds \n', 
         f'Log likelihood: {phase2_result.log_likelihood} \n', 
         f'Model: {str(phase2_result.model)} \n', '\n'] # set lines to write the model result
log.writelines(lines) # write lines
log.close()
# Out:
# Log likelihood: 163.12567460341367
# Model: Galaxy (elliptical_comps_0, GaussianPrior, mean = -0.12091435428141925, sigma = 0.3834496602337272), (elliptical_comps_1, GaussianPrior, mean = 0.2343720367847074, sigma = 0.40316819858068653), (intensity, GaussianPrior, mean = 0.05327837349927905, sigma = 0.053457071609182116), (effective_radius, GaussianPrior, mean = 1.8721355646722821, sigma = 1.8721355646722821), (sersic_index, GaussianPrior, mean = 2.579741735636044, sigma = 3.288079141762924), (mass_to_light_ratio, GaussianPrior, mean = 181.8572165584121, sigma = 876600.6750142531), (mass_at_200, GaussianPrior, mean = 648246628092.3497, sigma = 855339469584063.2), Galaxy (centre_0, GaussianPrior, mean = 0.17950319923088398, sigma = 3.1452481122322196), (centre_1, GaussianPrior, mean = -0.2460993764355576, sigma = 3.200838299782494), (intensity, GaussianPrior, mean = 0.0032364826225853866, sigma = 497809.84392553405), (effective_radius, GaussianPrior, mean = 2.6099664545813908, sigma = 2.6099664545813908), None, None

# %%
# append performance log
data_list = [[experiment_number, 
            phase1_time,
            phase1_result.log_likelihood,
            phase2_time, 
            phase2_result.log_likelihood,
             ]]
new_dataframe_entry = pd.DataFrame(data_list,
                                  columns=['Experiment', 
                                           'phase1_time', 
                                           'phase1_likelihood', 
                                           'phase2_time', 
                                           'phase2_likelihood', 
                                           ])
performance_log = pd.concat([performance_log, new_dataframe_entry])
print(performance_log)
performance_log.to_csv(f'{csv_path}G{gama_id}_{links_id}_performance_log.csv')
#print(phase_result.model)
# get samples to see how it ran?
#log_likelihoods = phase_result.samples.log_likelihoods
#x = np.arange(0, len(log_likelihoods), 1)
#plt.plot(x[500:], log_likelihoods[500:])
#plt.xlim()

# plot it!
fit_imaging_plotter = aplt.FitImagingPlotter(fit=phase2_result.max_log_likelihood_fit)
fit_imaging_plotter.subplot_fit_imaging()
# Out:
#   Experiment  phase1_time  phase1_likelihood  phase2_time  phase2_likelihood
# 0          1   403.158289         445.398771  1164.151751         163.125675

# %%
aplt.show()
